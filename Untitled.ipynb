# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('rfc_clean_train.csv')
test = pd.read_csv('rfc_clean_test.csv')

# %%
train.shape,test.shape
# Out:
# ((59400, 24), (14850, 23))

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 24 columns):
# Unnamed: 0             59400 non-null int64
# id                     59400 non-null int64
# status_group           59400 non-null object
# amount_tsh             59400 non-null float64
# days_since_recorded    59400 non-null int64
# funder                 59400 non-null object
# gps_height             59400 non-null float64
# installer              59400 non-null object
# longitude              59400 non-null float64
# latitude               59400 non-null float64
# basin                  59400 non-null object
# region                 59400 non-null object
# district_code          59400 non-null int64
# lga                    59400 non-null object
# population             59400 non-null float64
# scheme_management      59400 non-null object
# construction_year      59400 non-null float64
# extraction_type        59400 non-null object
# management             59400 non-null object
# payment_type           59400 non-null object
# water_quality          59400 non-null object
# quantity               59400 non-null object
# source                 59400 non-null object
# waterpoint_type        59400 non-null object
# dtypes: float64(6), int64(4), object(14)
# memory usage: 10.9+ MB

# %%
#drop this unnamed column 
train.drop('Unnamed: 0', axis=1, inplace=True)
test.drop('Unnamed: 0', axis=1, inplace=True)

train.drop(['id'],axis=1, inplace=True) # Because ids are not important for training.
target = train.pop('status_group')

# %%
# factorization of train data.(str -> int)
train['funder'] = pd.factorize(train['funder'])[0]
train['scheme_management'] = pd.factorize(train['scheme_management'])[0]
train['extraction_type'] = pd.factorize(train['extraction_type'])[0]
train['management'] = pd.factorize(train['management'])[0]
train['payment_type'] = pd.factorize(train['payment_type'])[0]
train['water_quality'] = pd.factorize(train['water_quality'])[0]
train['quantity'] = pd.factorize(train['quantity'])[0]
train['source'] = pd.factorize(train['source'])[0]
train['waterpoint_type'] = pd.factorize(train['waterpoint_type'])[0]
train['basin'] = pd.factorize(train['basin'])[0]
train['region'] = pd.factorize(train['region'])[0]
train['lga'] = pd.factorize(train['lga'])[0]
train['district_code'] = pd.factorize(train['district_code'])[0]
# train['operational_year'] = pd.factorize(train['operational_year'])[0]
train['installer'] = pd.factorize(train['installer'])[0]

# train.info()

# %%
# factorization of test data.(str -> int)
test['funder'] = pd.factorize(test['funder'])[0]
test['scheme_management'] = pd.factorize(test['scheme_management'])[0]
test['extraction_type'] = pd.factorize(test['extraction_type'])[0]
test['management'] = pd.factorize(test['management'])[0]
test['payment_type'] = pd.factorize(test['payment_type'])[0]
test['water_quality'] = pd.factorize(test['water_quality'])[0]
test['quantity'] = pd.factorize(test['quantity'])[0]
test['source'] = pd.factorize(test['source'])[0]
test['waterpoint_type'] = pd.factorize(test['waterpoint_type'])[0]
test['basin'] = pd.factorize(test['basin'])[0]
test['region'] = pd.factorize(test['region'])[0]
test['lga'] = pd.factorize(test['lga'])[0]
test['district_code'] = pd.factorize(test['district_code'])[0]
# test['operational_year'] = pd.factorize(test['operational_year'])[0]
test['installer'] = pd.factorize(test['installer'])[0]

# test.info()

# %%
from xgboost import XGBClassifier
model = XGBClassifier(objective = 'multi:softmax', booster = 'gbtree', nrounds = 'min.error.idx', 
                      num_class = 3, maximize = False, eval_metric = 'merror', eta = .2,
                      max_depth = 14, colsample_bytree = .4, verbose = 10)

# %% [raw]
# X = train
# y = target
# model.fit(X,y)

# %%
# splitting train data to train-test. We can use this labeled test for accuracy calculation.
from sklearn.model_selection import train_test_split

X = train
y = target

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# model.fit(X_train,y_train)
# model.fit(X_train,y_train).score(X_test, y_test)

# %% [raw]
# # k-fold evaluation.
#
# from sklearn.model_selection import cross_val_score
# print(cross_val_score(model, X, y, cv=5))
#
# # data.groupby(['status_group']).size()  checking result like this.

# %% [raw]
# importances = model.feature_importances_
# importances
#
# # importance decreases as increasing order.
# indices = np.argsort(importances)[::-1]
#
# print(importances)
# print(indices)
#
# # Print the feature ranking
# print("Feature ranking highest to lower:")
#
# print(X.shape[1])
#
# for f in range(X.shape[1]):
#     print(X.columns[indices[f]],end=', ')

# %% [raw]
# # feature elimination
#
# dropped_column = train.pop('gps_height')
# X = train
#
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# model.fit(X_train,y_train).score(X_test, y_test)

# %% [raw]
# dropped_column = train.pop('basin')
#
# X = train
#
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# # print(X_train.info())
# model.fit(X_train,y_train).score(X_test, y_test)

# %% [raw]
# dropped_column = train.pop('population')
#
# X = train
#
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# print(X_train.info())
# model.fit(X_train,y_train).score(X_test, y_test)

# %% [raw]
# # feature elimination one by one.
#
# from numpy import sort
# from sklearn.feature_selection import SelectFromModel
#
# thresholds = sort(model.feature_importances_)
# for thresh in thresholds:
#     # select features using threshold
#     selection = SelectFromModel(model, threshold=thresh, prefit=True)
#     select_X_train = selection.transform(X_train)
#     select_X_test = selection.transform(X_test)
#     # train model
#     selection_model = XGBClassifier()
#     score = selection_model.fit(select_X_train, y_train).score(select_X_test, y_test)
#     print(score)

# %%
print(train.shape)
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import RFE

for i in range(1, train.shape[1]):
    rfe = RFE(model, n_features_to_select=i)
    # rfe_result = rfe.fit(X_train, y_train)
    # rfe_score = rfe_result.score(X_test, y_test)
    
    
    print(cross_val_score(rfe, X, y, cv=5))
    
    print(rfe_score)
    print(rfe_result.support_)
    # print(rfe.ranking_)
# Out:
# (59400, 21)
# [17:02:16] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:02:26] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:02:38] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:02:48] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:02:58] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:03:07] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:03:18] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:03:27] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:03:36] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:03:45] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:03:55] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:04:03] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:04:13] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:04:21] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:04:29] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:04:34] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:04:38] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:04:41] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:04:43] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:04:44] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [17:04:45] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:04:46] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:04:56] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:05:07] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:05:17] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:05:26] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:05:34] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:05:43] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:05:52] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:06:01] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:06:10] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:06:19] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:06:29] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:06:39] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:06:46] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:06:57] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:07:03] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:07:06] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:07:09] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:07:10] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [17:07:11] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:07:12] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:07:12] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:07:22] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:07:32] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:07:41] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [17:07:50] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1593723605503/work/src/learner.cc:480:
# Parameters: { maximize, nrounds, verbose } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
